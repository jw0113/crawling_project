# %%
import pandas as pd

df = pd.read_excel('./crawling_data/11.xlsx')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 429 entries, 0 to 428
# Data columns (total 56 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      429 non-null    int64
#  1   D_TRA1_CASE     429 non-null    int64
#  2   D_TRA1_SMONTH   429 non-null    int64
#  3   D_TRA1_SDAY     429 non-null    int64
#  4   D_TRA1_EMONTH   429 non-null    int64
#  5   D_TRA1_EDAY     429 non-null    int64
#  6   A2_1            429 non-null    int64
#  7   A3_1            429 non-null    int64
#  8   A3_2            429 non-null    int64
#  9   A3_3            429 non-null    int64
#  10  A3_4            429 non-null    int64
#  11  A3_5            429 non-null    int64
#  12  A3_6            429 non-null    int64
#  13  A3_7            429 non-null    int64
#  14  A3_8            429 non-null    int64
#  15  A3_9            429 non-null    int64
#  16  A3_10           429 non-null    int64
# ...

# %%
import matplotlib.pyplot as plt
# f,ax = plt.subplots(1, 2, figsize = (10, 5))
# sex = df['SEX']
# print(sex)
# age = df['AGE']
# print(age)
# #sex['1'].value_counts
# df[df['SEX'] == 1].value_counts().plot

# df[df['SEX'] == 2].value_counts().plot
# ax[0].set_title('Male')
# ax[1].set_title('Female')
# plt.show()

plt.plot(df)
plt.show()

# %%
plt.plot(df['AGE'],df['SEX'],'ro')
plt.show()

# %%
import seaborn as sns

tips = sns.load_dataset("tips")

sns.relplot(x="AGE", y="N_A10", hue="SEX",data=df)

# %%
sns.relplot(x="A6_1", y="N_A10", hue="SEX",data=df)
#호텔과 여행비용의 상관관계

# %%
import pandas as pd
data_file = pd.read_excel("C:\\Users\\jiwoo\\Git\\datacrawling_project\\datas.xlsx")
data_file[data_file["O_TRA1_1_NATION1"]==223].to_excel("C:\\Users\\jiwoo\\Git\\datacrawling_project\\223.xlsx",encoding="utf-8")

# %%
#지역별 나이 분석
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df = pd.read_excel('C:\\Users\\jiwoo\\Git\\datacrawling_project\\223.xlsx')

seven = 0
six = 0
four = 0
two = 0
one = 0
five = 0
three = 0
eight = 0
for i in range(0,len(df)):
    if df['AGE_1YEAR_UNIT'][i] >= 10 and df['AGE_1YEAR_UNIT'][i] < 20:
        one = one + 1
    if df['AGE_1YEAR_UNIT'][i] >= 20 and df['AGE_1YEAR_UNIT'][i] < 30:
        two = two + 1
    if df['AGE_1YEAR_UNIT'][i] >= 30 and df['AGE_1YEAR_UNIT'][i] < 40:
        three = three + 1
    if df['AGE_1YEAR_UNIT'][i] >= 40 and df['AGE_1YEAR_UNIT'][i] < 50:
        four = four + 1
    if df['AGE_1YEAR_UNIT'][i] >= 50 and df['AGE_1YEAR_UNIT'][i] < 60:
        five = five + 1
    if df['AGE_1YEAR_UNIT'][i] >= 60 and df['AGE_1YEAR_UNIT'][i] < 70:
        six = six + 1
    if df['AGE_1YEAR_UNIT'][i] >= 70 and df['AGE_1YEAR_UNIT'][i] < 80:
        seven = seven + 1
    if df['AGE_1YEAR_UNIT'][i] >= 80 and df['AGE_1YEAR_UNIT'][i] < 90:
        eight = eight + 1

age = [one, two, three, four, five, six, seven, eight]

x = np.arange(10, 90, 10)
generation = ['10','20', '30', '40', '50', '60', '70', '80']

plt.bar(x, age, color='y',width=1.0)

plt.xticks(x, generation)

plt.show()

# %%
#지역별 성별 분석
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df = pd.read_excel('C:\\Users\\jiwoo\\Git\\datacrawling_project\\223.xlsx')

male = 0
female = 0

for i in range(0,len(df)):
    if df['BSEX'][i] == 1:
        male =male + 1
    else:
        female = female +1

sex = [male, female]
x = np.arange(0,2)
xname = ['male','female']

plt.bar(x, sex, color='r',width=0.2)

plt.xticks(x, xname)

plt.show()

# %%
#지역별 여행유형
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df = pd.read_excel('C:\\Users\\jiwoo\\Git\\datacrawling_project\\223.xlsx')

four = 0
two = 0
one = 0
five = 0
three = 0

for i in range(0,len(df)):
    if df['AA3_1'][i] == 1:
        one = one + 1
    if df['AA3_2'][i] == 2:
        two = two + 1
    if df['AA3_3'][i] == 3:
        three = three + 1
    if df['AA3_8'][i] == 8:
        four = four + 1
    if df['AA3_9'][i] == 9:
        five = five + 1
        
category = [one, two, three, four, five]
x = np.arange(0,5)
xname = ['famous','food', 'activity', 'shopping', 'concert']

plt.bar(x, category, color='b',width=0.4)

plt.xticks(x, xname)

plt.show()

# %%
#지역별 나이 분석
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df = pd.read_excel('C:\\Users\\jiwoo\\Git\\datacrawling_project\\223.xlsx')

spring = 0
summer = 0
autumn = 0
winter = 0
for i in range(0,len(df)):
    if df['O_TRA1_SMONTH'][i] >= 3 and df['O_TRA1_SMONTH'][i] < 7:
        spring = spring + 1
    if df['O_TRA1_SMONTH'][i] >= 7 and df['O_TRA1_SMONTH'][i] < 10:
        summer = summer + 1
    if df['O_TRA1_SMONTH'][i] >= 9 and df['O_TRA1_SMONTH'][i] < 12:
        autumn = autumn + 1
    if df['O_TRA1_SMONTH'][i] == 12 or df['O_TRA1_SMONTH'][i] ==1 or df['O_TRA1_SMONTH'][i] ==2:
        winter = winter + 1
    
season = [spring, summer, autumn, winter]

x = np.arange(0,4)
xname = ['spring', 'summer', 'autumn', 'winter']

plt.bar(x, season, color='green',width=0.4)

plt.xticks(x, xname)

plt.show()

# %%
#데이터 파일 정리
import pandas as pd

#파일 읽어오기
data_file = pd.read_excel("./data.xlsx")

data_file[data_file["MON_EXP_OVER_ALL"]==1].to_excel("./datas.xlsx",encoding="utf-8")

# %%
data_file = pd.read_excel("C:\\Users\\jiwoo\\Git\\datacrawling_project\\datas.xlsx")
data_file[data_file["O_TRA1_1_NATION1"] == 007 ].to_excel("C:\\Users\\jiwoo\\Git\\datacrawling_project\\007.xlsx",encoding="utf-8")
