://www.tripadvisor.co.kr/Attractions-g2023520-Activities-Jeollabuk_do.html
    
충청남도
https://www.tripadvisor.co.kr/Attractions-g1072096-Activities-Chungcheongnam_do.html
    
경상남도
https://www.tripadvisor.co.kr/Attractions-g1072104-Activities-Gyeongsangnam_do.html
    
충청북도
https://www.tripadvisor.co.kr/Attractions-g2023524-Activities-Chungcheongbuk_do.html

경상북도
https://www.tripadvisor.co.kr/Attractions-g2023521-Activities-Gyeongsangbuk_do.html
    
전라남도
https://www.tripadvisor.co.kr/Attractions-g1072086-Activities-Jeollanam_do.html

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import pandas as pd
import numpy as np


review_list=[]
#def tripadvisor:
for i in range(0,10,10):
    url_str = "https://www.tripadvisor.co.kr/Attraction_Review-g294197-d324888-Reviews-or"
    url_num = str(i)
    url_keyword = "-Gyeongbokgung_Palace-Seoul.html"

    total_url = url_str + url_num + url_keyword
    driver = webdriver.Chrome('/Users/parkjiyun/Downloads/chromedriver')
    driver.get(total_url)

    time.sleep(3)
    


    for j in range(0,10,1):
        
        reviews = driver.find_elements_by_xpath("//*[@id='tab-data-qa-reviews-0']/div/div[5]/div" )
        rating_code = reviews[j].find_element_by_css_selector("svg.RWYkj.d.H0")
        
        #평점
        cls_attr = rating_code.get_attribute("title")
        cls_attr = str(cls_attr).split("풍선 5개 중 ")

        #평점 작업하기
        score = str(cls_attr[1])
        time.sleep(3)

        #본문
        Temp_review = reviews[j].find_element_by_css_selector("div.pIRBV._T.KRIav > div > span.NejBf").text
        time.sleep(3)
        review = Temp_review.replace("\n", " ")
        
#         #리뷰 제목과 작성자
#         title = reviews[j].find_element_by_css_selector("span.NejBf").text
#         writer = reviews[j].find_element_by_css_selector("a.iPqaD._F.G-.ddFHE.eKwUx.btBEK.fUpii").text
#         time.sleep(3)
#         if score == "5.0" or score == "4.0":
#             label = 1
#         if score == "2.0" or score == "1.0":
#             label = 0
        
        review_list.append([review, score])
        print('=========>', score)
        
    
colList = ['review', 'score']
df = pd.DataFrame(np.array(review_list), columns=colList)
df.to_csv('Gyeongbokgung_Palace-Seoul.csv', encoding='UTF-8', index = True)
# Out:
# =========> 5.0
# =========> 5.0
# =========> 5.0
# =========> 5.0
# =========> 5.0
# =========> 5.0
# =========> 5.0
# =========> 5.0
# =========> 4.0
# =========> 5.0

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import pandas as pd
import numpy as np

review_list=[]
url = "https://www.tripadvisor.co.kr/Attraction_Review-g294197-d324888-Reviews-Gyeongbokgung_Palace-Seoul.html"
driver = webdriver.Chrome('/Users/parkjiyun/Downloads/chromedriver')
driver.get(url)
time.sleep(3)

reviews = driver.find_elements_by_xpath("//*[@id='tab-data-qa-reviews-0']/div/div[5]/div")
rating_code = reviews[0].find_element_by_css_selector("svg.RWYkj.d.H0")
cls_attr = rating_code.get_attribute("title")
cls_attr = str(cls_attr).split("풍선 5개 중 ")
score = str(cls_attr[1])
time.sleep(3)

#tab-data-qa-reviews-0 > div > div.dHjBB > div:nth-child(1) > span > span > div.duhwe._T.bOlcm > div.pIRBV._T.KRIav > div > span
Temp_review = reviews[5].find_element_by_css_selector("div.pIRBV._T.KRIav > div > span.NejBf").text
time.sleep(3)
review = Temp_review.replace("\n", " ")

# title = reviews[5].find_element_by_css_selector("span.NejBf").text
# writer = reviews[5].find_element_by_css_selector("a.iPqaD._F.G-.ddFHE.eKwUx.btBEK.fUpii").text
# time.sleep(3)

# if score == "5.0" or score == "4.0":
#     label = 1
# if score == "2.0" or score == "1.0":
#     label = 0
# if score == "3.0":
#     label = '-'

review_list.append([review, score])
colList = ['review', 'score']
df = pd.DataFrame(np.array(review_list), columns=colList)
df.to_csv('Gyeongbokgung_Palace-Seoul.csv', encoding='UTF-8')

driver.quit()

# %%
driver.quit()

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import pandas as pd
import numpy as np

review_list=[]
url = "https://www.tripadvisor.co.kr/Attraction_Review-g294197-d554528-Reviews-Bukhansan_National_Park-Seoul.html"
driver = webdriver.Chrome('/Users/parkjiyun/Downloads/chromedriver')
driver.get(url)
time.sleep(3)

for j in range(0,10,1):

    reviews = driver.find_elements_by_xpath("//*[@id='tab-data-qa-reviews-0']/div/div[5]/div" )
    rating_code = reviews[j].find_element_by_css_selector("svg.RWYkj.d.H0")

    #평점
    cls_attr = rating_code.get_attribute("title")
    cls_attr = str(cls_attr).split("풍선 5개 중 ")

    #평점 작업하기
    score = str(cls_attr[1])
    time.sleep(3)

    #본문
    Temp_review = reviews[j].find_element_by_css_selector("div.pIRBV._T.KRIav > div > span.NejBf").text
    time.sleep(3)
    review = Temp_review.replace("\n", " ")

#         #리뷰 제목과 작성자
#         title = reviews[j].find_element_by_css_selector("span.NejBf").text
#         writer = reviews[j].find_element_by_css_selector("a.iPqaD._F.G-.ddFHE.eKwUx.btBEK.fUpii").text
#         time.sleep(3)
#         if score == "5.0" or score == "4.0":
#             label = 1
#         if score == "2.0" or score == "1.0":
#             label = 0

    review_list.append([review, score])
    print('=========>', score)

    
colList = ['review', 'score']
df = pd.DataFrame(np.array(review_list), columns=colList)
df.to_csv('Bukhansan_National_Park-Seoul.csv', encoding='UTF-8')
# Out:
# =========> 좋아요
# =========> 좋아요
# =========> 좋아요
# =========> 좋아요
# =========> 좋아요
# =========> 좋아요
# =========> 좋아요
# =========> 좋아요
# =========> 좋아요
# =========> 좋아요

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import pandas as pd
import numpy as np
from selenium.webdriver.chrome.options import Options

options = Options()
options.headless = True
html_list=["https://www.tripadvisor.co.kr/Attractions-g294197-Activities-a_allAttractions.true-Seoul.html","https://www.tripadvisor.co.kr/Attractions-g294197-Activities-c61-Seoul.html", "https://www.tripadvisor.co.kr/Attractions-g294197-Activities-c58-Seoul.html", "https://www.tripadvisor.co.kr/Attractions-g294197-Activities-c36-Seoul.html", "https://www.tripadvisor.co.kr/Attractions-g294197-Activities-c26-Seoul.html"]
data_list=[]
#def tripadvisor:
for i in range(0,5):
    total_url = html_list[i]
    driver = webdriver.Chrome('/Users/parkjiyun/Downloads/chromedriver')
    driver.get(total_url)

    time.sleep(3)
    if i == 0:
        category = 1
    if i == 1:
        category = 2
    if i == 2:
        category = 3
    if i == 3:
        category = 4
    if i == 4:
        category = 5
        
        #lithium-root > main > span > div > div.FrWCV.z.bFzKI > div > div:nth-child(2) > div.JzhQk._T > span > div > div:nth-child(2) > div > div.eAbRL._T > div > div > section:nth-child(7) > div > span > div > article > div.MGdFu.P0 > div > div > div >
        #lithium-root > main > span > div > div.FrWCV.z.bFzKI > div > div:nth-child(2) > div.JzhQk._T > span > div > div:nth-child(2) > div > div.eAbRL._T > div > div > section:nth-child(8) > div > span > div > article > div.MGdFu.P0 > div > div > div > div.cNjlV > div > svg > path:nth-child(1)
        #lithium-root > main > span > div > div.FrWCV.z.bFzKI > div > div:nth-child(2) > div.JzhQk._T > span > div > div:nth-child(2) > div > div.eAbRL._T > div > div > section:nth-child(9) > div > span > div > article > div.MGdFu.P0 > div > div > div > div.cNjlV > div > svg > path:nth-child(1)
        #lithium-root > main > span > div > div.FrWCV.z.bFzKI > div > div:nth-child(2) > div.JzhQk._T > span > div > div:nth-child(2) > div > div.eAbRL._T > div > div > section:nth-child(2) > div > span > div > article > div.MGdFu.P0 > div > div > div > div.cNjlV > div > div > div > div > div.wClCt.w > a > ul > li.bBdQR._A.bxQEm > picture > img

    for j in range(0,6):
#         location = driver.find_element_by_css_selector("#lithium-root > main > span > div > div.dqRmR.cyevx.dcDXR.dJjeH > div > div > div:nth-child(3) > a > span > span.WlYyy.diXIH.brhTq.bQCoY").text
        
#         temp_title = driver.find_elements_by_css_selector("div.bUshh.o.csemS")
#         temp_title2 = temp_title[j].text
#         title = temp_title2[3:]
# #         if j != 9:
# #             title = temp_title2[3:]
# #         else:
# #             title = temp_title2[4:]
#         images = driver.find_elements_by_css_selector("li.bBdQR._A.bxQEm > picture > img")
        
#         for image in images: 
#             links.append(image.get_attribute('src'))

#         urllib.request.urlretrieve(links[j], "./webcrawling_img/Seoul/" + title + ".jpg")
#         print('---다운로드 완료---')
        
    
#         data_list.append([location, category, title])
#         print('=========>', title)
        a = j+2
        #lithium-root > main > span > div > div.FrWCV.z.bFzKI > div > div:nth-child(2) > div.JzhQk._T > span > div > div:nth-child(2) > div > div.eAbRL._T > div > div > section:nth-child(3) > div > span > div > article
        #lithium-root > main > span > div > div.FrWCV.z.bFzKI > div > div:nth-child(2) > div.JzhQk._T > span > div > div:nth-child(2) > div > div.eAbRL._T > div > div > section:nth-child(3) > div > span > div > article > div.MGdFu.P0 > div > div > div > div.cNjlV > div > div > div > div > div.wClCt.w > a > ul > li.bBdQR._A.bxQEm > picture > img
        #temp[j] = driver.find_element_by_css_selector("#lithium-root > main > span > div > div.FrWCV.z.bFzKI > div > div:nth-child(2) > div.JzhQk._T > span > div > div:nth-child(2) > div > div.eAbRL._T > div > div > section:nth-child(" + str(a) + ") > div > span > div > article")
        print(temp[j])
        image = temp[j].find_element_by_css_selector("img")
        link = image.get_attribute('src')
        temp_title = temp[j].find_element_by_css_selector("div.bUshh.o.csemS")
        temp_title2 = temp_title.text
        title = temp_title2[3:]
        urllib.request.urlretrieve(link, "./webcrawling_img/Seoul/" + title + ".jpg")
        print('---다운로드 완료---')
               
        data_list.append([location, category, title])
    driver.quit()
        
    
colList = ['location', 'category', 'title']
df = pd.DataFrame(np.array(data_list), columns=colList)
df.to_csv('./webcrawling_data/Seoul.csv', encoding='UTF-8', index = True)
#print(df)
driver.quit()
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="b35e45ee2a7e4471142af7331a0d24de", element="3369a925-dc6e-4d01-bb7e-67526a25762f")>
# ---다운로드 완료---
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-43-c41322ccd657> in <module>
#      57         #lithium-root > main > span > div > div.FrWCV.z.bFzKI > div > div:nth-child(2) > div.JzhQk._T > span > div > div:nth-child(2) > div > div.eAbRL._T > div > div > section:nth-child(3) > div > span > div > article
#      58         #lithium-root > main > span > div > div.FrWCV.z.bFzKI > div > div:nth-child(2) > div.JzhQk._T > span > div > div:nth-child(2) > div > div.eAbRL._T > div > div > section:nth-child(3) > div > span > div > article > div.MGdFu.P0 > div > div > div > div.cNjlV > div > div > div > div > div.wClCt.w > a > ul > li.bBdQR._A.bxQEm > picture > img
# ...

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import pandas as pd
import numpy as np
from selenium.webdriver.chrome.options import Options

options = Options()
options.headless = True
html_list=["https://www.tripadvisor.co.kr/Attractions-g1072089-Activities-a_allAttractions.true-Gyeonggi_do.html", "https://www.tripadvisor.co.kr/Attractions-g1072089-Activities-c61-Gyeonggi_do.html","https://www.tripadvisor.co.kr/Attractions-g1072089-Activities-c58-Gyeonggi_do.html", "https://www.tripadvisor.co.kr/Attractions-g1072089-Activities-c36-Gyeonggi_do.html", "https://www.tripadvisor.co.kr/Attractions-g1072089-Activities-c26-Gyeonggi_do.html"]
data_list=[]
#def tripadvisor:
for i in range(0,5):
    total_url = html_list[i]
    driver = webdriver.Chrome('/Users/parkjiyun/Downloads/chromedriver')
    driver.get(total_url)

    time.sleep(3)
    if i == 0:
        category = 1
    if i == 1:
        category = 2
    if i == 2:
        category = 3
    if i == 3:
        category = 4
    if i == 4:
        category = 5


    for j in range(0,10,1):
        location = driver.find_element_by_css_selector("#lithium-root > main > span > div > div.dqRmR.cyevx.dcDXR.dJjeH > div > div > div:nth-child(3) > a > span > span.WlYyy.diXIH.brhTq.bQCoY").text
        
        temp_title = driver.find_elements_by_css_selector("div.bUshh.o.csemS")
        temp_title2 = temp_title[j].text
        if j != 9:
            title = temp_title2[3:]
        else:
            title = temp_title2[4:]
        images = driver.find_elements_by_css_selector("li.bBdQR._A.bxQEm > picture > img")
        
        for image in images: 
            if image.get_attribute('src')!=None: 
                links.append(image.get_attribute('src'))
            if

        urllib.request.urlretrieve(links[j], "./webcrawling_img/Gyeonggi_do/" + title + ".jpg")
        print('---다운로드 완료---')
        
        
        data_list.append([location, category, title])
        print('=========>', title)
        
    driver.quit()
        
    
colList = ['location', 'category', 'title']
df = pd.DataFrame(np.array(data_list), columns=colList)
df.to_csv('./webcrawling_data/Gyeonggi_do.csv', encoding='UTF-8', index = True)
#print(df)
driver.quit()
# Out:
# ---다운로드 완료---
# =========> 에버랜드
# ---다운로드 완료---
# =========> DMZ
# ---다운로드 완료---
# =========> 수원화성
# ---다운로드 완료---
# =========> 아침 고요 수목원
# ---다운로드 완료---
# =========> Dae Jang Geum Theme Park
# ---다운로드 완료---
# =========> 한국민속촌
# ---다운로드 완료---
# =========> 부락산
# ---다운로드 완료---
# =========> 일산 호수 공원
# ---다운로드 완료---
# =========> Imjingak Resort
# ---다운로드 완료---
# =========> 서울대공원
# ---다운로드 완료---
# =========> 부락산
# ---다운로드 완료---
# =========> 서울대공원
# ---다운로드 완료---
# =========> 지산포레스트리조트
# ---다운로드 완료---
# =========> 부천자연생태공원
# ---다운로드 완료---
# =========> 한화 아쿠아플라넷 일산
# ---다운로드 완료---
# =========> 베어스 타운 리조트
# ---다운로드 완료---
# =========> 농협중앙회 안성팜랜드
# ---다운로드 완료---
# =========> 주렁주렁 - 하남점
# ---다운로드 완료---
# =========> 플레이아쿠아리움 부천
# ---다운로드 완료---
# =========> 가평사계절썰매장
# ---다운로드 완료---
# =========> 서부문예회관
# ---다운로드 완료---
# =========> 평촌아트홀
# ---다운로드 완료---
# =========> 안성 남사당공연장
# ---다운로드 완료---
# =========> 더잼존부천
# ---다운로드 완료---
# =========> 복사골 문화센터 아트홀
# ---다운로드 완료---
# =========> M-camp 아트센터
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-29-604bacf1b0f6> in <module>
#      45         try:
# ---> 46             temp[j] = driver.find_element_by_css_selector("#lithium-root > main > span > div > div.FrWCV.z.bFzKI > div > div:nth-child(2) > div.JzhQk._T > span > div > div:nth-child(2) > div > div.eAbRL._T > div > div > section:nth-child(" + str(j) + ") > div > span > div > article")
#      47             try:
#
# IndexError: list assignment index out of range
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-29-604bacf1b0f6> in <module>
#      62
#      63         except:
# ---> 64             temp[j] = '-'
#      65
#      66         if temp[j] == '-':
#
# IndexError: list assignment index out of range

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import pandas as pd
import numpy as np
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time
import os
import urllib.request


options = Options()
options.headless = True

data_list=[]
links=[]
url = ["https://www.tripadvisor.co.kr/Attractions-g294197-Activities-a_allAttractions.true-Seoul.html"]
driver = webdriver.Chrome('/Users/parkjiyun/Downloads/chromedriver')
driver.get(url[0])
time.sleep(3)
#lithium-root > main > span > div > div.FrWCV.z.bFzKI > div > div:nth-child(2) > div.JzhQk._T > span > div > div:nth-child(2) > div > div.eAbRL._T > div > div
location = driver.find_element_by_css_selector("#lithium-root > main > span > div > div.dqRmR.cyevx.dcDXR.dJjeH > div > div > div:nth-child(3) > a > span > span.WlYyy.diXIH.brhTq.bQCoY").text

#lithium-root > main > span > div > div.FrWCV.z.bFzKI > div > div:nth-child(2) > div.JzhQk._T > span > div > div:nth-child(2) > div > div.eAbRL._T > div > div > section:nth-child(2) > div > span > div > article
#lithium-root > main > span > div > div.FrWCV.z.bFzKI > div > div:nth-child(2) > div.JzhQk._T > span > div > div:nth-child(2) > div > div.eAbRL._T > div > div > section:nth-child(3) > div > span > div > article

# temp_title = driver.find_elements_by_css_selector("#lithium-root > main > span > div > div.FrWCV.z.bFzKI > div > div:nth-child(2) > div.JzhQk._T > span > div > div:nth-child(2) > div > div.eAbRL._T > div > div > section")
# temp_title2 = temp_title[j].find_elements_by_css_selector("div > span > div > article")
# title = temp_title2.find_elements_by_css_selector("div.eLWnh.P0 > header > div > div > a:nth-child(1) > h3 > div > span > div.bUshh.o.csemS").text

temp_title = driver.find_elements_by_css_selector("div.bUshh.o.csemS")
title = temp_title[0].text
print(title)

images = driver.find_elements_by_css_selector("li.bBdQR._A.bxQEm > picture > img")
print(len(images))

for image in images: 
    if image.get_attribute('src')!=None: 
        links.append(image.get_attribute('src'))
print(links)
        
for i in range(0,10):
    urllib.request.urlretrieve(links[i], "./webcrawling_img/" + str(i) + ".jpg")
    print(' 다운로드 중.......')
print('---다운로드 완료---')


#lithium-root > main > span > div > div.FrWCV.z.bFzKI > div > div:nth-child(2) > div.JzhQk._T > span > div > div:nth-child(2) > div > div.eAbRL._T > div > div > section:nth-child(2) > div > span > div > article > div.MGdFu.P0 > div > div > div > div.cNjlV > div > div > div > div > div.wClCt.w > a > ul > li.bBdQR._A.bxQEm > picture > img
#lithium-root > main > span > div > div.FrWCV.z.bFzKI > div > div:nth-child(2) > div.JzhQk._T > span > div > div:nth-child(2) > div > div.eAbRL._T > div > div > section:nth-child(3) > div > span > div > article > div.MGdFu.P0 > div > div > div > div.cNjlV > div > div > div > div > div.wClCt.w > a > ul > li.bBdQR._A.bxQEm > picture > img

#data_list.append([location, category, title])
# colList = ['location', 'category', 'title']
# df = pd.DataFrame(np.array(data_list), columns=colList)
# #df.to_csv('Gyeongbokgung_Palace-Seoul.csv', encoding='UTF-8')
# print(df)

driver.quit()
# Out:
# 1. 경복궁
# 30
# ...

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import pandas as pd
import numpy as np
from selenium.webdriver.chrome.options import Options

options = Options()
options.headless = True
html_list=["https://www.tripadvisor.co.kr/Attractions-g294197-Activities-a_allAttractions.true-Seoul.html","https://www.tripadvisor.co.kr/Attractions-g294197-Activities-c61-Seoul.html", "https://www.tripadvisor.co.kr/Attractions-g294197-Activities-c58-Seoul.html", "https://www.tripadvisor.co.kr/Attractions-g294197-Activities-c36-Seoul.html", "https://www.tripadvisor.co.kr/Attractions-g294197-Activities-c26-Seoul.html"]
html_list2=["https://www.tripadvisor.co.kr/Attractions-g1072089-Activities-a_allAttractions.true-Gyeonggi_do.html", "https://www.tripadvisor.co.kr/Attractions-g1072089-Activities-c61-Gyeonggi_do.html","https://www.tripadvisor.co.kr/Attractions-g1072089-Activities-c58-Gyeonggi_do.html", "https://www.tripadvisor.co.kr/Attractions-g1072089-Activities-c36-Gyeonggi_do.html", "https://www.tripadvisor.co.kr/Attractions-g1
://www.tripadvisor.co.kr/Attractions-g2023520-Activities-c61-Jeollabuk_do.html", "https://www.tripadvisor.co.kr/Attractions-g2023520-Activities-c58-Jeollabuk_do.html","https://www.tripadvisor.co.kr/Attractions-g2023520-Activities-c26-Jeollabuk_do.html"]
html_list12 = ["https://www.tripadvisor.co.kr/Attractions-g1072086-Activities-a_allAttractions.true-Jeollanam_do.html","https://www.tripadvisor.co.kr/Attractions-g1072086-Activities-c61-Jeollanam_do.html","https://www.tripadvisor.co.kr/Attractions-g1072086-Activities-c58-Jeollanam_do.html", "https://www.tripadvisor.co.kr/Attractions-g1072086-Activities-c36-Jeollanam_do.html", "https://www.tripadvisor.co.kr/Attractions-g1072086-Activities-c26-Jeollanam_do.html"]
html_list13 = ["https://www.tripadvisor.co.kr/Attractions-g1072096-Activities-a_allAttractions.true-Chungcheongnam_do.html","https://www.tripadvisor.co.kr/Attractions-g1072096-Activities-c61-Chungcheongnam_do.html", "https://www.tripadvisor.co.kr/Attractions-g1072096-Activities-c58-Chungcheongnam_do.html", "https://www.tripadvisor.co.kr/Attractions-g1072096-Activities-c36-Chungcheongnam_do.html", "https://www.tripadvisor.co.kr/Attractions-g1072096-Activities-c26-Chungcheongnam_do.html"]
html_list14 = ["https://www.tripadvisor.co.kr/Attractions-g2023524-Activities-a_allAttractions.true-Chungcheongbuk_do.html", "https://www.tripadvisor.co.kr/Attractions-g2023524-Activities-c61-Chungcheongbuk_do.html", "https://www.tripadvisor.co.kr/Attractions-g2023524-Activities-c36-Chungcheongbuk_do.html", "https://www.tripadvisor.co.kr/Attractions-g2023524-Activities-c26-Chungcheongbuk_do.html"]
html_list15 = ["https://www.tripadvisor.co.kr/Attractions-g1072104-Activities-a_allAttractions.true-Gyeongsangnam_do.html","https://www.tripadvisor.co.kr/Attractions-g1072104-Activities-c61-Gyeongsangnam_do.html", "https://www.tripadvisor.co.kr/Attractions-g1072104-Activities-c58-Gyeongsangnam_do.html", "https://www.tripadvisor.co.kr/Attractions-g1072104-Activities-c36-Gyeongsangnam_do.html", "https://www.tripadvisor.co.kr/Attractions-g1072104-Activities-c26-Gyeongsangnam_do.html"]
html_list16 = ["https://www.tripadvisor.co.kr/Attractions-g2023521-Activities-a_allAttractions.true-Gyeongsangbuk_do.html","https://www.tripadvisor.co.kr/Attractions-g2023521-Activities-c61-Gyeongsangbuk_do.html","https://www.tripadvisor.co.kr/Attractions-g2023521-Activities-c58-Gyeongsangbuk_do.html", "https://www.tripadvisor.co.kr/Attractions-g2023521-Activities-c26-Gyeongsangbuk_do.html"]

data_list=[]
#def tripadvisor:
for i in range(0,4):
    total_url = html_list16[i]
    driver = webdriver.Chrome('/Users/parkjiyun/Downloads/chromedriver')
    driver.get(total_url)

    time.sleep(3)
    if i == 0:
        category = 1
    if i == 1:
        category = 2
    if i == 2:
        category = 3
    if i == 3:
        category = 5
    if i == 4:
        category = 5


    for j in range(0,5):
        location = driver.find_element_by_css_selector("#lithium-root > main > span > div > div.dqRmR.cyevx.dcDXR.dJjeH > div > div > div:nth-child(3) > a > span > span.WlYyy.diXIH.brhTq.bQCoY").text
        
        temp_title = driver.find_elements_by_css_selector("div.bUshh.o.csemS")
        temp_title2 = temp_title[j].text
        title = temp_title2[3:]
#         if j != 9:
#             title = temp_title2[3:]
#         else:
#             title = temp_title2[4:]
        #images = driver.find_elements_by_css_selector("li.bBdQR._A.bxQEm > picture > img")
        
#         for image in images: 
#             if image.get_attribute('src')!=None: 
#                 links.append(image.get_attribute('src'))
#             if

#         urllib.request.urlretrieve(links[j], "./webcrawling_img/Gyeonggi_do/" + title + ".jpg")
#         print('---다운로드 완료---')
        
        
        data_list.append([location, category, title])
        print('=========>', title)
        
    driver.quit()
        
    
colList = ['location', 'category', 'title']
df = pd.DataFrame(np.array(data_list), columns=colList)
df.to_csv('./webcrawling_data/Gyeongsangbuk_do.csv', encoding='UTF-8', index = True)
#print(df)
driver.quit()
# Out:
# =========> 불국사
# =========> 죽도 시장
# =========> 안동하회마을
# =========> 안압지
# =========> 국립경주박물관
# =========> 영일대해수욕장
# =========> 영덕 블루로드
# =========> 금오산 저수지
# =========> 문장대
# =========> 칠포해수욕장
# =========> 천마아트센터
# =========> 포항문화예술회관
# =========> 경주 서라벌문화회관
# =========> 플라잉
# =========> 정동극장
# =========> 죽도 시장
# =========> 성동시장
# =========> 안동구시장
# =========> 안동중앙신시장
# =========> 진보시장

# %%
data = df['title']
#print(data[1])
import urllib.request
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from urllib.request import urlretrieve
from tqdm import tqdm
import time

import os

def get_images(keyword):
    driver = webdriver.Chrome('/Users/parkjiyun/Downloads/chromedriver')
    driver.implicitly_wait(30)
    url = "https://search.naver.com/search.naver?sm=tab_hty.top&where=image&query={}".format(keyword)
    driver.get(url)
    
    image = driver.find_element_by_css_selector("#main_pack > section.sc_new.sp_nimage._prs_img._imageSearchPC > div > div.photo_group._listGrid > div.photo_tile._grid > div:nth-child(1) > div > div.thumb > a > img")
    link = image.get_attribute('src')
    driver.quit()
    urllib.request.urlretrieve(link, "./webcrawling_img/Gyeongsangbuk_do/" + keyword + ".jpg")
    print(keyword + '\t다운로드 완료')

if __name__ == '__main__':
    for i in range(0,20):
        keyword = data[i]
        get_images(keyword)
# Out:
# 불국사	다운로드 완료
# 죽도 시장	다운로드 완료
# 안동하회마을	다운로드 완료
# 안압지	다운로드 완료
# 국립경주박물관	다운로드 완료
# 영일대해수욕장	다운로드 완료
# 영덕 블루로드	다운로드 완료
# 금오산 저수지	다운로드 완료
# 문장대	다운로드 완료
# 칠포해수욕장	다운로드 완료
# 천마아트센터	다운로드 완료
# 포항문화예술회관	다운로드 완료
# 경주 서라벌문화회관	다운로드 완료
# 플라잉	다운로드 완료
# 정동극장	다운로드 완료
# 죽도 시장	다운로드 완료
# 성동시장	다운로드 완료
# 안동구시장	다운로드 완료
# 안동중앙신시장	다운로드 완료
# 진보시장	다운로드 완료

# %%
driver = webdriver.Chrome('/Users/parkjiyun/Downloads/chromedriver')
url = "https://www.tripadvisor.co.kr/Attractions-g297884-Activities-c36-Busan.html"
driver.get(url)

#image = driver.find_element_by_css_selector("#lithium-root > main > span > div > div.FrWCV.z.bFzKI > div > div:nth-child(2) > div.JzhQk._T > span > div > div:nth-child(2) > div > div.eAbRL._T > div > div > section:nth-child(5) > div > span > div > article > div.MGdFu.P0 > div > div > div > div.cNjlV > div > div > div > div > div.wClCt.w > a > ul > li.bBdQR._A.bxQEm > picture > img")
#image = driver.find_element_by_css_selector("#lithium-root > main > span > div > div.FrWCV.z.bFzKI > div > div:nth-child(2) > div.JzhQk._T > span > div > div:nth-child(2) > div > div.eAbRL._T > div > div > section:nth-child(6) > div > span > div > article > div.MGdFu.P0 > div > div > div > div.cNjlV > div > div > div > div > div.wClCt.w > a > ul > li.bBdQR._A.bxQEm > picture > img")
image = driver.find_element_by_css_selector("#lithium-root > main > span > div > div.FrWCV.z.bFzKI > div > div:nth-child(2) > div.JzhQk._T > span > div > div:nth-child(2) > div > div.eAbRL._T > div > div > section:nth-child(7) > div > span > div > article > div.MGdFu.P0 > div > div > div > div.cNjlV > div > div > div > div > div.wClCt.w > a > ul > li.bBdQR._A.bxQEm > picture > img")
link = image.get_attribute('src')
urllib.request.urlretrieve(link, "./webcrawling_img/Busan/주노트립 쿠킹클래스 인 부산.jpg")

driver.quit()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-83-c3e8fcef2eab> in <module>
#       7 image = driver.find_element_by_css_selector("#lithium-root > main > span > div > div.FrWCV.z.bFzKI > div > div:nth-child(2) > div.JzhQk._T > span > div > div:nth-child(2) > div > div.eAbRL._T > div > div > section:nth-child(7) > div > span > div > article > div.MGdFu.P0 > div > div > div > div.cNjlV > div > div > div > div > div.wClCt.w > a > ul > li.bBdQR._A.bxQEm > picture > img")
#       8 link = image.get_attribute('src')
# ----> 9 urllib.request.urlretrieve(link, "./webcrawling_img/Busan/주노트립 쿠킹클래스 인 부산.jpg")
#      10
#      11 driver.quit()
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     245     url_type, path = _splittype(url)
#     246
# --> 247     with contextlib.closing(urlopen(url, data)) as fp:
# ...

# %%
driver = webdriver.Chrome('/Users/parkjiyun/Downloads/chromedriver')
url = "https://www.tripadvisor.co.kr/Attractions-g983296-Activities-c36-Jeju_Island.html"
driver.get(url)
#lithium-root > main > span > div > div.FrWCV.z.bFzKI > div > div:nth-child(2) > div.JzhQk._T > span > div > div:nth-child(2) > div > div.eAbRL._T > div > div > section:nth-child(12) > div > span > div > article > div.MGdFu.P0 > div > div > div > div.cNjlV > div > div > div > div > div.wClCt.w > a > ul > li.bBdQR._A.bxQEm > picture > img
image = driver.find_element_by_css_selector("#lithium-root > main > span > div > div.FrWCV.z.bFzKI > div > div:nth-child(2) > div.JzhQk._T > span > div > div:nth-child(2) > div > div.eAbRL._T > div > div > section:nth-child(10) > div > span > div > article > div.MGdFu.P0 > div > div > div > div.cNjlV > div > div > div > div > div.wClCt.w > a > ul > li.bBdQR._A.bxQEm > picture > img")
link = image.get_attribute('src')
urllib.request.urlretrieve(link, "./webcrawling_img/Jeju_Island/투데이즈 프렌드.jpg")

#lithium-root > main > span > div > div.FrWCV.z.bFzKI > div > div:nth-child(2) > div.JzhQk._T > span > div > div:nth-child(2) > div > div.eAbRL._T > div > div > section:nth-child(10) > div > span > div > article > div.MGdFu.P0 > div > div > div > div.cNjlV > div > div > div > div > div.wClCt.w > a > ul > li.bBdQR._A.bxQEm > picture > img
driver.quit()
